# %%
import seaborn as sns
from sys import getsizeof

# %%
lens=[]
with open('data/1.txt') as f:
    for line in f:
        lens.append(len(line))

getsizeof(lens) / 1024 / 1024
# Out:
# 84.96776580810547

# %%
sns.histplot(lens)
# Out:
# <AxesSubplot:ylabel='Count'>
